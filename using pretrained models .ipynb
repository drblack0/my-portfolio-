# %%
import matplotlib.pyplot as plt
import keras_ocr as koc

# %%
pipeline = koc.pipeline.Pipeline()
# Out:
# Looking for C:\Users\LENOVO\.keras-ocr\craft_mlt_25k.h5
# Downloading C:\Users\LENOVO\.keras-ocr\craft_mlt_25k.h5
# Looking for C:\Users\LENOVO\.keras-ocr\crnn_kurapan.h5
# Downloading C:\Users\LENOVO\.keras-ocr\crnn_kurapan.h5

# %%
images = [
    koc.tools.read(url) for url in [
        'https://upload.wikimedia.org/wikipedia/commons/b/bd/Army_Reserves_Recruitment_Banner_MOD_45156284.jpg',
        'https://upload.wikimedia.org/wikipedia/commons/b/b4/EUBanana-500x112.jpg'
    ]
]

# %%
prediction_groups = pipeline.recognize(images)
# Out:
# 1/1 [==============================] - 50s 50s/step
# 2/2 [==============================] - 5s 362ms/step

# %%
fig, axs = plt.subplots(nrows=len(images), figsize=(20, 20))
for ax, image, predictions in zip(axs, images, prediction_groups):
    koc.tools.drawAnnotations(image=image, predictions=predictions, ax=ax)
